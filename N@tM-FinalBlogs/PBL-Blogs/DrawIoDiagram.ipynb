# %%
GameObject
│
├── Background
│  ├── BackgroundParallax
│  ├── BackgroundSnow
│  ├── BackgroundSnowfall
│  └── BackgroundTransitions
│
├── Character
│  ├── Boss
│  │  └── BossItem
│  ├── ChocoFrog
│  ├── Coin
│  ├── Cutstory
│  ├── darkMode
│  ├── Document
│  ├── FinishLine
│  ├── FlyingDementor
│  ├── FlyingDragon
│  ├── FlyingEnemy
│  ├── FlyingEnemyOneD
│  ├── FlyingGoomba
│  ├── FlyingJellyfish
│  ├── FlyingOwl
│  ├── FlyingUFO
│  ├── Laser
│  ├── Lava
│  ├── Leaderboard
│  ├── lightMode
│  ├── LocalStorage
│  ├── MagicBeam
│  ├── Multiplayer
│  ├── Mushroom
│  ├── NarwhalBoss
│  ├── RandomEvent
│  ├── SettingsControl
│  ├── SkibidiTitan
│  ├── SkibidiToilet
│  ├── Sound
│  ├── Star
│  └── toggleTheme
│
├── Enemy
│  ├── EnemyCerberus
│  ├── EnemyDraco
│  ├── EnemyFishies
│  ├── EnemyGoomba
│  ├── EnemyPenguin
│  ├── EnemySnowman
│  └── EnemyTurtle
│
├── Platform
│  ├── PlatformBase
│  ├── PlatformFilter
│  ├── PlatformFlyingIsland
│  ├── PlatformJump
│  ├── PlatformMoving
│  └── PlatformSpawn
│
├── PlayerBase
│  ├── PlayerBaseOneD
│  ├── PlayerBoss
│  ├── PlayerGreece
│  ├── PlayerHills
│  ├── PlayerIce
│  ├── PlayerMini
│  ├── PlayerMiniHogwarts
│  ├── PlayerQuidditch
│  ├── PlayerSkibidi
│  ├── PlayerWater
│  ├── PlayerWinter
│  └── PlayerZombie
│
├── Game Environment and Control
│  ├── GameControl
│  ├── GameEnv
│  ├── GameLevel
│  ├── GameSet
│  ├── GameSetterBoss
│  ├── GameSetterEnd
│  ├── GameSetterGreece
│  ├── GameSetterGreeceMini
│  ├── GameSetterHills
│  ├── GameSetterHogwarts
│  ├── GameSetterQuidditch
│  ├── GameSetterSkibidi
│  ├── GameSetterStart
│  ├── GameSetterWater
│  ├── GameSetterWinter
│  ├── GameSetterWinterIce
│  └── GameSetup
│
└── hpBar
